# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd

from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90, 90, 2000)
lngs = np.random.uniform(-180, 180, 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
# zip returns ITERATOR OF TUPLES
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
nearest_city = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in nearest_city:
        nearest_city.append(city)
        

# Print the city count to confirm sufficient count
pd.Series(nearest_city).head(10)
# Out:
# 0       kasane
# 1    mahebourg
# 2       samusu
# 3    hithadhoo
# 4    cape town
# 5       hasaki
# 6       atuona
# 7       barrow
# 8     saleaula
# 9         poya
# dtype: object

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?"

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# I want to see what the JSON looks like
url = url + 'q=' + 'Toronto' + '&appid=' + weather_api_key
url
# Out:
# 'https://api.openweathermap.org/data/2.5/weather?q=Toronto&appid=2f87bca941b52b46d553c78ac7d78c6a'

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(nearest_city):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+") + "&appid=" + weather_api_key
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # YOUR CODE HERE
        
        lat = city_weather['coord']['lat']
        lng = city_weather['coord']['lon']
        country = city_weather['sys']['country']
        max_temp = city_weather['main']['temp_max']
        prcnt_humidity = city_weather['main']['humidity']
        prcnt_cloudiness = city_weather['clouds']['all']
        wind_speed = city_weather['wind']['speed']
        weather_description = city_weather['weather'][0]['description']
        
        # Append the city information into the city_data list
        # YOUR CODE HERE
    
        city_data.append({
            'City': city.title(),
            'Country': country,
            'Lat': lat,
            'Lng': lng,
            'Max Temp': max_temp,
            'Humidity': prcnt_humidity,
            'Cloudiness': prcnt_cloudiness,
            'Wind Speed': wind_speed,
            'Current Description': weather_description
            
        })
    
    # If an error is experienced, skip the city
    except:
        print(f"{city} not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | amderma
# amderma not found. Skipping...
# Processing Record 2 of Set 1 | provideniya
# Processing Record 3 of Set 1 | sistranda
# Processing Record 4 of Set 1 | sur
# Processing Record 5 of Set 1 | port hardy
# Processing Record 6 of Set 1 | saint-philippe
# Processing Record 7 of Set 1 | khatanga
# Processing Record 8 of Set 1 | esperance
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | san patricio
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | richards bay
# Processing Record 14 of Set 1 | ciudad bolivar
# Processing Record 15 of Set 1 | tuatapere
# Processing Record 16 of Set 1 | vaitupu
# vaitupu not found. Skipping...
# Processing Record 17 of Set 1 | puerto ayora
# Processing Record 18 of Set 1 | gamba
# Processing Record 19 of Set 1 | bengkulu
# Processing Record 20 of Set 1 | mahina
# Processing Record 21 of Set 1 | mount isa
# Processing Record 22 of Set 1 | longyearbyen
# Processing Record 23 of Set 1 | port blair
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | marcona
# marcona not found. Skipping...
# Processing Record 26 of Set 1 | puerto del rosario
# Processing Record 27 of Set 1 | hobart
# Processing Record 28 of Set 1 | ancud
# Processing Record 29 of Set 1 | codrington
# Processing Record 30 of Set 1 | ulladulla
# Processing Record 31 of Set 1 | hilo
# Processing Record 32 of Set 1 | saint george
# Processing Record 33 of Set 1 | mahebourg
# Processing Record 34 of Set 1 | zwedru
# Processing Record 35 of Set 1 | carnarvon
# Processing Record 36 of Set 1 | lazaro cardenas
# Processing Record 37 of Set 1 | avarua
# Processing Record 38 of Set 1 | sysert
# Processing Record 39 of Set 1 | isangel
# Processing Record 40 of Set 1 | puerto madryn
# Processing Record 41 of Set 1 | tilichiki
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | paamiut
# Processing Record 44 of Set 1 | neuquen
# Processing Record 45 of Set 1 | mys shmidta
# mys shmidta not found. Skipping...
# Processing Record 46 of Set 1 | hithadhoo
# Processing Record 47 of Set 1 | norman wells
# Processing Record 48 of Set 1 | sinop
# Processing Record 49 of Set 1 | nouadhibou
# Processing Record 50 of Set 1 | berbera
# Processing Record 1 of Set 2 | new norfolk
# Processing Record 2 of Set 2 | manaus
# Processing Record 3 of Set 2 | severo-kurilsk
# Processing Record 4 of Set 2 | torbay
# Processing Record 5 of Set 2 | tandil
# Processing Record 6 of Set 2 | yermakovskoye
# Processing Record 7 of Set 2 | yanam
# Processing Record 8 of Set 2 | mataura
# Processing Record 9 of Set 2 | kroya
# Processing Record 10 of Set 2 | port elizabeth
# Processing Record 11 of Set 2 | cape town
# Processing Record 12 of Set 2 | maceio
# Processing Record 13 of Set 2 | brae
# Processing Record 14 of Set 2 | sept-iles
# Processing Record 15 of Set 2 | ozu
# Processing Record 16 of Set 2 | qaanaaq
# Processing Record 17 of Set 2 | taolanaro
# taolanaro not found. Skipping...
# Processing Record 18 of Set 2 | araouane
# Processing Record 19 of Set 2 | nikolskoye
# Processing Record 20 of Set 2 | georgetown
# Processing Record 21 of Set 2 | yellowknife
# Processing Record 22 of Set 2 | bonthe
# Processing Record 23 of Set 2 | antofagasta
# Processing Record 24 of Set 2 | hermanus
# Processing Record 25 of Set 2 | bluff
# Processing Record 26 of Set 2 | shubarshi
# Processing Record 27 of Set 2 | muros
# Processing Record 28 of Set 2 | goulburn
# Processing Record 29 of Set 2 | udachnyy
# Processing Record 30 of Set 2 | jamestown
# Processing Record 31 of Set 2 | belushya guba
# belushya guba not found. Skipping...
# Processing Record 32 of Set 2 | luganville
# Processing Record 33 of Set 2 | kenai
# Processing Record 34 of Set 2 | port alfred
# Processing Record 35 of Set 2 | tsihombe
# tsihombe not found. Skipping...
# Processing Record 36 of Set 2 | atuona
# Processing Record 37 of Set 2 | asilah
# Processing Record 38 of Set 2 | san quintin
# Processing Record 39 of Set 2 | upernavik
# Processing Record 40 of Set 2 | cagayan de tawi-tawi
# cagayan de tawi-tawi not found. Skipping...
# Processing Record 41 of Set 2 | aksarka
# Processing Record 42 of Set 2 | san felipe
# Processing Record 43 of Set 2 | deputatskiy
# Processing Record 44 of Set 2 | victoria
# Processing Record 45 of Set 2 | letterkenny
# Processing Record 46 of Set 2 | dikson
# Processing Record 47 of Set 2 | yulara
# Processing Record 48 of Set 2 | vardo
# Processing Record 49 of Set 2 | east london
# Processing Record 50 of Set 2 | shache
# Processing Record 1 of Set 3 | pandrup
# Processing Record 2 of Set 3 | nakamura
# Processing Record 3 of Set 3 | chokurdakh
# Processing Record 4 of Set 3 | guerrero negro
# Processing Record 5 of Set 3 | ahipara
# Processing Record 6 of Set 3 | wuda
# Processing Record 7 of Set 3 | samusu
# samusu not found. Skipping...
# Processing Record 8 of Set 3 | santa maria
# Processing Record 9 of Set 3 | serowe
# Processing Record 10 of Set 3 | rehoboth
# Processing Record 11 of Set 3 | ondo
# Processing Record 12 of Set 3 | kamenka
# Processing Record 13 of Set 3 | sao joao da barra
# Processing Record 14 of Set 3 | ritchie
# Processing Record 15 of Set 3 | peniche
# Processing Record 16 of Set 3 | oistins
# Processing Record 17 of Set 3 | los llanos de aridane
# Processing Record 18 of Set 3 | maldonado
# Processing Record 19 of Set 3 | busselton
# Processing Record 20 of Set 3 | airai
# Processing Record 21 of Set 3 | nauta
# Processing Record 22 of Set 3 | linchuan
# linchuan not found. Skipping...
# Processing Record 23 of Set 3 | chase
# Processing Record 24 of Set 3 | bhatapara
# Processing Record 25 of Set 3 | illoqqortoormiut
# illoqqortoormiut not found. Skipping...
# Processing Record 26 of Set 3 | pangnirtung
# Processing Record 27 of Set 3 | namwala
# Processing Record 28 of Set 3 | podor
# Processing Record 29 of Set 3 | cidreira
# Processing Record 30 of Set 3 | north bend
# Processing Record 31 of Set 3 | roald
# Processing Record 32 of Set 3 | chuy
# Processing Record 33 of Set 3 | nuuk
# Processing Record 34 of Set 3 | kozluk
# Processing Record 35 of Set 3 | mackay
# Processing Record 36 of Set 3 | dengzhou
# Processing Record 37 of Set 3 | sorong
# Processing Record 38 of Set 3 | marawi
# Processing Record 39 of Set 3 | aklavik
# Processing Record 40 of Set 3 | grand river south east
# grand river south east not found. Skipping...
# Processing Record 41 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 42 of Set 3 | hirado
# Processing Record 43 of Set 3 | rocha
# Processing Record 44 of Set 3 | tura
# Processing Record 45 of Set 3 | independencia
# Processing Record 46 of Set 3 | laguna
# Processing Record 47 of Set 3 | ende
# Processing Record 48 of Set 3 | vila franca do campo
# Processing Record 49 of Set 3 | mezen
# Processing Record 50 of Set 3 | safwah
# safwah not found. Skipping...
# Processing Record 1 of Set 4 | bethel
# Processing Record 2 of Set 4 | nizhneyansk
# nizhneyansk not found. Skipping...
# Processing Record 3 of Set 4 | port lincoln
# Processing Record 4 of Set 4 | matamoros
# Processing Record 5 of Set 4 | esfarayen
# Processing Record 6 of Set 4 | saint-augustin
# Processing Record 7 of Set 4 | clermont
# Processing Record 8 of Set 4 | novobirilyussy
# Processing Record 9 of Set 4 | vaini
# Processing Record 10 of Set 4 | bredasdorp
# Processing Record 11 of Set 4 | itarema
# Processing Record 12 of Set 4 | asyut
# Processing Record 13 of Set 4 | newport
# Processing Record 14 of Set 4 | luba
# Processing Record 15 of Set 4 | grand baie
# Processing Record 16 of Set 4 | lakatoro
# Processing Record 17 of Set 4 | wenling
# Processing Record 18 of Set 4 | sentyabrskiy
# sentyabrskiy not found. Skipping...
# Processing Record 19 of Set 4 | novogurovskiy
# Processing Record 20 of Set 4 | dicabisagan
# Processing Record 21 of Set 4 | formoso do araguaia
# formoso do araguaia not found. Skipping...
# Processing Record 22 of Set 4 | saryshagan
# saryshagan not found. Skipping...
# Processing Record 23 of Set 4 | imeni morozova
# Processing Record 24 of Set 4 | huanren
# Processing Record 25 of Set 4 | geraldton
# Processing Record 26 of Set 4 | hofn
# Processing Record 27 of Set 4 | clearwater
# Processing Record 28 of Set 4 | buala
# Processing Record 29 of Set 4 | talnakh
# Processing Record 30 of Set 4 | tumsar
# Processing Record 31 of Set 4 | barranca
# Processing Record 32 of Set 4 | ribeira grande
# Processing Record 33 of Set 4 | vestmannaeyjar
# Processing Record 34 of Set 4 | karpathos
# Processing Record 35 of Set 4 | aloguinsan
# Processing Record 36 of Set 4 | tarko-sale
# Processing Record 37 of Set 4 | castro
# Processing Record 38 of Set 4 | strezhevoy
# Processing Record 39 of Set 4 | kruisfontein
# Processing Record 40 of Set 4 | llata
# Processing Record 41 of Set 4 | lgov
# Processing Record 42 of Set 4 | le robert
# Processing Record 43 of Set 4 | kampot
# Processing Record 44 of Set 4 | carballo
# Processing Record 45 of Set 4 | katsuura
# Processing Record 46 of Set 4 | pevek
# Processing Record 47 of Set 4 | barrow
# Processing Record 48 of Set 4 | sens
# Processing Record 49 of Set 4 | likasi
# Processing Record 50 of Set 4 | tasiilaq
# Processing Record 1 of Set 5 | rungata
# rungata not found. Skipping...
# Processing Record 2 of Set 5 | eggenfelden
# Processing Record 3 of Set 5 | mar del plata
# Processing Record 4 of Set 5 | waterloo
# Processing Record 5 of Set 5 | san carlos
# Processing Record 6 of Set 5 | odienne
# Processing Record 7 of Set 5 | zabol
# Processing Record 8 of Set 5 | surt
# Processing Record 9 of Set 5 | cairns
# Processing Record 10 of Set 5 | sao filipe
# Processing Record 11 of Set 5 | klaksvik
# Processing Record 12 of Set 5 | northam
# Processing Record 13 of Set 5 | lagoa
# Processing Record 14 of Set 5 | adre
# Processing Record 15 of Set 5 | tigil
# Processing Record 16 of Set 5 | la ronge
# Processing Record 17 of Set 5 | road town
# Processing Record 18 of Set 5 | san policarpo
# Processing Record 19 of Set 5 | bambous virieux
# Processing Record 20 of Set 5 | port moresby
# Processing Record 21 of Set 5 | jinxiang
# Processing Record 22 of Set 5 | margate
# Processing Record 23 of Set 5 | asbe teferi
# Processing Record 24 of Set 5 | rio gallegos
# Processing Record 25 of Set 5 | mount gambier
# Processing Record 26 of Set 5 | salalah
# Processing Record 27 of Set 5 | nau
# Processing Record 28 of Set 5 | coihaique
# Processing Record 29 of Set 5 | kuruman
# Processing Record 30 of Set 5 | lillesand
# Processing Record 31 of Set 5 | avera
# Processing Record 32 of Set 5 | weatherford
# Processing Record 33 of Set 5 | hualmay
# Processing Record 34 of Set 5 | arraial do cabo
# Processing Record 35 of Set 5 | komsomolskiy
# Processing Record 36 of Set 5 | padang
# Processing Record 37 of Set 5 | saleaula
# saleaula not found. Skipping...
# Processing Record 38 of Set 5 | umzimvubu
# umzimvubu not found. Skipping...
# Processing Record 39 of Set 5 | skiros
# skiros not found. Skipping...
# Processing Record 40 of Set 5 | askarovo
# Processing Record 41 of Set 5 | nishihara
# Processing Record 42 of Set 5 | praya
# Processing Record 43 of Set 5 | lebu
# Processing Record 44 of Set 5 | mantua
# Processing Record 45 of Set 5 | andenes
# Processing Record 46 of Set 5 | kodiak
# Processing Record 47 of Set 5 | san rafael
# Processing Record 48 of Set 5 | barentsburg
# barentsburg not found. Skipping...
# Processing Record 49 of Set 5 | vao
# Processing Record 50 of Set 5 | havre-saint-pierre
# Processing Record 1 of Set 6 | meulaboh
# Processing Record 2 of Set 6 | beloha
# Processing Record 3 of Set 6 | port augusta
# Processing Record 4 of Set 6 | attawapiskat
# attawapiskat not found. Skipping...
# Processing Record 5 of Set 6 | milyutinskaya
# Processing Record 6 of Set 6 | nunoa
# Processing Record 7 of Set 6 | masunga
# Processing Record 8 of Set 6 | saint anthony
# Processing Record 9 of Set 6 | hambantota
# Processing Record 10 of Set 6 | palora
# Processing Record 11 of Set 6 | carmo do rio claro
# Processing Record 12 of Set 6 | saint-joseph
# Processing Record 13 of Set 6 | acari
# Processing Record 14 of Set 6 | jinchengjiang
# jinchengjiang not found. Skipping...
# Processing Record 15 of Set 6 | paysandu
# Processing Record 16 of Set 6 | kharp
# Processing Record 17 of Set 6 | kalmunai
# Processing Record 18 of Set 6 | praia da vitoria
# Processing Record 19 of Set 6 | laramie
# Processing Record 20 of Set 6 | cabedelo
# Processing Record 21 of Set 6 | tupancireta
# Processing Record 22 of Set 6 | ndende
# Processing Record 23 of Set 6 | saint-francois
# Processing Record 24 of Set 6 | cherskiy
# Processing Record 25 of Set 6 | khandyga
# Processing Record 26 of Set 6 | boralday
# Processing Record 27 of Set 6 | soyo
# Processing Record 28 of Set 6 | butaritari
# Processing Record 29 of Set 6 | senanga
# Processing Record 30 of Set 6 | kavaratti
# Processing Record 31 of Set 6 | loudeac
# Processing Record 32 of Set 6 | dunmore town
# Processing Record 33 of Set 6 | sitka
# Processing Record 34 of Set 6 | utinga
# Processing Record 35 of Set 6 | tianguismanalco
# Processing Record 36 of Set 6 | adrar
# Processing Record 37 of Set 6 | fortuna
# Processing Record 38 of Set 6 | ilulissat
# Processing Record 39 of Set 6 | ilinskiy
# Processing Record 40 of Set 6 | balakhta
# Processing Record 41 of Set 6 | santa cruz de la palma
# Processing Record 42 of Set 6 | kajaani
# Processing Record 43 of Set 6 | tuktoyaktuk
# Processing Record 44 of Set 6 | batticaloa
# Processing Record 45 of Set 6 | andros town
# Processing Record 46 of Set 6 | makurdi
# Processing Record 47 of Set 6 | alyangula
# Processing Record 48 of Set 6 | biltine
# Processing Record 49 of Set 6 | qaqortoq
# Processing Record 50 of Set 6 | bahia blanca
# Processing Record 1 of Set 7 | veraval
# Processing Record 2 of Set 7 | bonao
# Processing Record 3 of Set 7 | labuhan
# Processing Record 4 of Set 7 | port hedland
# Processing Record 5 of Set 7 | banda aceh
# Processing Record 6 of Set 7 | gold coast
# Processing Record 7 of Set 7 | manakara
# Processing Record 8 of Set 7 | nyurba
# Processing Record 9 of Set 7 | tecoanapa
# Processing Record 10 of Set 7 | ponta do sol
# Processing Record 11 of Set 7 | tres arroyos
# Processing Record 12 of Set 7 | sobolevo
# Processing Record 13 of Set 7 | thompson
# Processing Record 14 of Set 7 | faanui
# Processing Record 15 of Set 7 | kirakira
# Processing Record 16 of Set 7 | umm kaddadah
# Processing Record 17 of Set 7 | vanavara
# Processing Record 18 of Set 7 | tansen
# Processing Record 19 of Set 7 | morgantown
# Processing Record 20 of Set 7 | terrace bay
# Processing Record 21 of Set 7 | corat
# Processing Record 22 of Set 7 | alice springs
# Processing Record 23 of Set 7 | colac
# Processing Record 24 of Set 7 | tunduru
# tunduru not found. Skipping...
# Processing Record 25 of Set 7 | banjar
# Processing Record 26 of Set 7 | tupik
# Processing Record 27 of Set 7 | mitsamiouli
# Processing Record 28 of Set 7 | verkhnyaya inta
# Processing Record 29 of Set 7 | dasoguz
# Processing Record 30 of Set 7 | biak
# Processing Record 31 of Set 7 | magdagachi
# Processing Record 32 of Set 7 | alta floresta
# Processing Record 33 of Set 7 | zhigansk
# Processing Record 34 of Set 7 | curuca
# Processing Record 35 of Set 7 | haines junction
# Processing Record 36 of Set 7 | beringovskiy
# Processing Record 37 of Set 7 | santa quiteria do maranhao
# Processing Record 38 of Set 7 | dingle
# Processing Record 39 of Set 7 | imbituba
# Processing Record 40 of Set 7 | campos
# Processing Record 41 of Set 7 | broome
# Processing Record 42 of Set 7 | camopi
# Processing Record 43 of Set 7 | kahului
# Processing Record 44 of Set 7 | vyazemskiy
# Processing Record 45 of Set 7 | ixtapa
# Processing Record 46 of Set 7 | acajutla
# Processing Record 47 of Set 7 | westport
# Processing Record 48 of Set 7 | port macquarie
# Processing Record 49 of Set 7 | sioux lookout
# Processing Record 50 of Set 7 | zambezi
# Processing Record 1 of Set 8 | loubomo
# Processing Record 2 of Set 8 | clyde river
# Processing Record 3 of Set 8 | kupang
# Processing Record 4 of Set 8 | tabat
# Processing Record 5 of Set 8 | ahuimanu
# Processing Record 6 of Set 8 | kuche
# kuche not found. Skipping...
# Processing Record 7 of Set 8 | udankudi
# Processing Record 8 of Set 8 | kudahuvadhoo
# Processing Record 9 of Set 8 | yishui
# Processing Record 10 of Set 8 | tuxpan
# Processing Record 11 of Set 8 | flinders
# Processing Record 12 of Set 8 | hohhot
# Processing Record 13 of Set 8 | souillac
# Processing Record 14 of Set 8 | tiksi
# Processing Record 15 of Set 8 | faya
# Processing Record 16 of Set 8 | samalaeulu
# samalaeulu not found. Skipping...
# Processing Record 17 of Set 8 | elizabeth city
# Processing Record 18 of Set 8 | san lorenzo
# Processing Record 19 of Set 8 | hamilton
# Processing Record 20 of Set 8 | saskylakh
# Processing Record 21 of Set 8 | mehamn
# Processing Record 22 of Set 8 | kaitangata
# Processing Record 23 of Set 8 | trairi
# Processing Record 24 of Set 8 | sisimiut
# Processing Record 25 of Set 8 | denizli
# Processing Record 26 of Set 8 | puerto escondido
# Processing Record 27 of Set 8 | hasaki
# Processing Record 28 of Set 8 | goderich
# Processing Record 29 of Set 8 | leh
# Processing Record 30 of Set 8 | khorixas
# Processing Record 31 of Set 8 | temaraia
# temaraia not found. Skipping...
# Processing Record 32 of Set 8 | harrai
# Processing Record 33 of Set 8 | selma
# Processing Record 34 of Set 8 | muscle shoals
# Processing Record 35 of Set 8 | wawina
# Processing Record 36 of Set 8 | iqaluit
# Processing Record 37 of Set 8 | wuwei
# Processing Record 38 of Set 8 | assiniboia
# Processing Record 39 of Set 8 | kayes
# Processing Record 40 of Set 8 | okhotsk
# Processing Record 41 of Set 8 | xichang
# Processing Record 42 of Set 8 | lingyuan
# Processing Record 43 of Set 8 | vostochnyy
# Processing Record 44 of Set 8 | poum
# Processing Record 45 of Set 8 | cockburn harbour
# cockburn harbour not found. Skipping...
# Processing Record 46 of Set 8 | martapura
# Processing Record 47 of Set 8 | guadalupe y calvo
# Processing Record 48 of Set 8 | sumbawa
# sumbawa not found. Skipping...
# Processing Record 49 of Set 8 | xadani
# xadani not found. Skipping...
# Processing Record 50 of Set 8 | fort-shevchenko
# Processing Record 1 of Set 9 | halalo
# halalo not found. Skipping...
# Processing Record 2 of Set 9 | redmond
# Processing Record 3 of Set 9 | maghama
# maghama not found. Skipping...
# Processing Record 4 of Set 9 | seoul
# Processing Record 5 of Set 9 | sakaiminato
# Processing Record 6 of Set 9 | tezu
# Processing Record 7 of Set 9 | matara
# Processing Record 8 of Set 9 | alta gracia
# Processing Record 9 of Set 9 | puerto ayacucho
# Processing Record 10 of Set 9 | san cristobal
# Processing Record 11 of Set 9 | sabha
# Processing Record 12 of Set 9 | tambul
# tambul not found. Skipping...
# Processing Record 13 of Set 9 | kloulklubed
# Processing Record 14 of Set 9 | coahuayana
# Processing Record 15 of Set 9 | ugoofaaru
# Processing Record 16 of Set 9 | kirovo-chepetsk
# Processing Record 17 of Set 9 | dhidhdhoo
# Processing Record 18 of Set 9 | kyra
# Processing Record 19 of Set 9 | gavrilovka vtoraya
# Processing Record 20 of Set 9 | siva
# Processing Record 21 of Set 9 | gushikawa
# Processing Record 22 of Set 9 | san mateo del mar
# Processing Record 23 of Set 9 | ongandjera
# Processing Record 24 of Set 9 | mastic beach
# Processing Record 25 of Set 9 | comodoro rivadavia
# Processing Record 26 of Set 9 | severo-yeniseyskiy
# Processing Record 27 of Set 9 | sar-e pul
# Processing Record 28 of Set 9 | alugan
# Processing Record 29 of Set 9 | naruja
# Processing Record 30 of Set 9 | bayburt
# Processing Record 31 of Set 9 | zachagansk
# zachagansk not found. Skipping...
# Processing Record 32 of Set 9 | nome
# Processing Record 33 of Set 9 | lolua
# lolua not found. Skipping...
# Processing Record 34 of Set 9 | vitim
# Processing Record 35 of Set 9 | price
# Processing Record 36 of Set 9 | masakin
# Processing Record 37 of Set 9 | meadow lake
# Processing Record 38 of Set 9 | ismailia
# Processing Record 39 of Set 9 | kavieng
# Processing Record 40 of Set 9 | chernigovka
# Processing Record 41 of Set 9 | lavrentiya
# Processing Record 42 of Set 9 | camacupa
# Processing Record 43 of Set 9 | umirim
# Processing Record 44 of Set 9 | nelson bay
# Processing Record 45 of Set 9 | karsava
# Processing Record 46 of Set 9 | katherine
# Processing Record 47 of Set 9 | buraydah
# Processing Record 48 of Set 9 | terrace
# Processing Record 49 of Set 9 | blonduos
# blonduos not found. Skipping...
# Processing Record 50 of Set 9 | paciran
# Processing Record 1 of Set 10 | freeport
# Processing Record 2 of Set 10 | abu samrah
# Processing Record 3 of Set 10 | donskoye
# Processing Record 4 of Set 10 | palmer
# Processing Record 5 of Set 10 | taoudenni
# Processing Record 6 of Set 10 | isla mujeres
# Processing Record 7 of Set 10 | heihe
# Processing Record 8 of Set 10 | ahraura
# Processing Record 9 of Set 10 | ostrovnoy
# Processing Record 10 of Set 10 | myaundzha
# Processing Record 11 of Set 10 | cardston
# Processing Record 12 of Set 10 | dunedin
# Processing Record 13 of Set 10 | bilma
# Processing Record 14 of Set 10 | nemuro
# Processing Record 15 of Set 10 | progress
# Processing Record 16 of Set 10 | louisbourg
# louisbourg not found. Skipping...
# Processing Record 17 of Set 10 | coquimbo
# Processing Record 18 of Set 10 | curup
# Processing Record 19 of Set 10 | ruatoria
# ruatoria not found. Skipping...
# Processing Record 20 of Set 10 | mingyue
# Processing Record 21 of Set 10 | takoradi
# Processing Record 22 of Set 10 | samarai
# Processing Record 23 of Set 10 | guarapari
# Processing Record 24 of Set 10 | matagami
# Processing Record 25 of Set 10 | te anau
# Processing Record 26 of Set 10 | vila
# Processing Record 27 of Set 10 | ponta delgada
# Processing Record 28 of Set 10 | presidente medici
# Processing Record 29 of Set 10 | kosh-agach
# Processing Record 30 of Set 10 | lipany
# Processing Record 31 of Set 10 | saint-pierre
# Processing Record 32 of Set 10 | nador
# Processing Record 33 of Set 10 | bambanglipuro
# Processing Record 34 of Set 10 | manhush
# Processing Record 35 of Set 10 | shirokiy
# Processing Record 36 of Set 10 | luderitz
# Processing Record 37 of Set 10 | skagastrond
# skagastrond not found. Skipping...
# Processing Record 38 of Set 10 | marzuq
# Processing Record 39 of Set 10 | uray
# Processing Record 40 of Set 10 | ati
# Processing Record 41 of Set 10 | atar
# Processing Record 42 of Set 10 | sorland
# Processing Record 43 of Set 10 | mbandaka
# Processing Record 44 of Set 10 | lysyanka
# Processing Record 45 of Set 10 | karratha
# Processing Record 46 of Set 10 | christchurch
# Processing Record 47 of Set 10 | daryapur
# Processing Record 48 of Set 10 | san rafael del sur
# Processing Record 49 of Set 10 | ambilobe
# Processing Record 50 of Set 10 | sirjan
# Processing Record 1 of Set 11 | curillo
# Processing Record 2 of Set 11 | sibolga
# Processing Record 3 of Set 11 | key west
# Processing Record 4 of Set 11 | olavarria
# Processing Record 5 of Set 11 | celestun
# Processing Record 6 of Set 11 | akdepe
# Processing Record 7 of Set 11 | nanortalik
# Processing Record 8 of Set 11 | baykit
# Processing Record 9 of Set 11 | wajima
# Processing Record 10 of Set 11 | farah
# Processing Record 11 of Set 11 | zimovniki
# Processing Record 12 of Set 11 | evensk
# Processing Record 13 of Set 11 | sao desiderio
# Processing Record 14 of Set 11 | yumen
# Processing Record 15 of Set 11 | remontnoye
# Processing Record 16 of Set 11 | rawson
# Processing Record 17 of Set 11 | yar-sale
# Processing Record 18 of Set 11 | raha
# Processing Record 19 of Set 11 | los andes
# Processing Record 20 of Set 11 | narsaq
# Processing Record 21 of Set 11 | turukhansk
# Processing Record 22 of Set 11 | leningradskiy
# Processing Record 23 of Set 11 | port-gentil
# Processing Record 24 of Set 11 | dingli
# Processing Record 25 of Set 11 | kristiinankaupunki
# Processing Record 26 of Set 11 | marsa matruh
# Processing Record 27 of Set 11 | grand gaube
# Processing Record 28 of Set 11 | ampanihy
# Processing Record 29 of Set 11 | dzilam gonzalez
# Processing Record 30 of Set 11 | volot
# Processing Record 31 of Set 11 | alofi
# Processing Record 32 of Set 11 | ust-kuyga
# Processing Record 33 of Set 11 | azangaro
# Processing Record 34 of Set 11 | lianran
# Processing Record 35 of Set 11 | half moon bay
# Processing Record 36 of Set 11 | kaili
# Processing Record 37 of Set 11 | myitkyina
# Processing Record 38 of Set 11 | mangan
# Processing Record 39 of Set 11 | odolena voda
# Processing Record 40 of Set 11 | shipitsyno
# Processing Record 41 of Set 11 | edmond
# Processing Record 42 of Set 11 | moundou
# Processing Record 43 of Set 11 | saldanha
# Processing Record 44 of Set 11 | portland
# Processing Record 45 of Set 11 | markova
# Processing Record 46 of Set 11 | vanimo
# Processing Record 47 of Set 11 | progreso
# Processing Record 48 of Set 11 | gazojak
# Processing Record 49 of Set 11 | plataresti
# Processing Record 50 of Set 11 | la palma
# Processing Record 1 of Set 12 | oro valley
# Processing Record 2 of Set 12 | lorengau
# Processing Record 3 of Set 12 | navodari
# Processing Record 4 of Set 12 | charters towers
# Processing Record 5 of Set 12 | limerick
# Processing Record 6 of Set 12 | san juan
# Processing Record 7 of Set 12 | sembakung
# Processing Record 8 of Set 12 | indramayu
# Processing Record 9 of Set 12 | sinkat
# sinkat not found. Skipping...
# Processing Record 10 of Set 12 | zhanaozen
# Processing Record 11 of Set 12 | cap malheureux
# Processing Record 12 of Set 12 | bathsheba
# Processing Record 13 of Set 12 | lixourion
# Processing Record 14 of Set 12 | tapaua
# tapaua not found. Skipping...
# Processing Record 15 of Set 12 | caravelas
# Processing Record 16 of Set 12 | hede
# Processing Record 17 of Set 12 | jacareacanga
# Processing Record 18 of Set 12 | nabul
# nabul not found. Skipping...
# Processing Record 19 of Set 12 | raudeberg
# Processing Record 20 of Set 12 | chapais
# Processing Record 21 of Set 12 | khurda
# Processing Record 22 of Set 12 | babanusah
# babanusah not found. Skipping...
# Processing Record 23 of Set 12 | hanover
# Processing Record 24 of Set 12 | sabzevar
# Processing Record 25 of Set 12 | clinton
# Processing Record 26 of Set 12 | owando
# Processing Record 27 of Set 12 | gorontalo
# Processing Record 28 of Set 12 | beihai
# Processing Record 29 of Set 12 | solnechnyy
# Processing Record 30 of Set 12 | huixtla
# Processing Record 31 of Set 12 | concordia
# Processing Record 32 of Set 12 | lasa
# Processing Record 33 of Set 12 | dargaville
# Processing Record 34 of Set 12 | cayenne
# Processing Record 35 of Set 12 | nguiu
# nguiu not found. Skipping...
# Processing Record 36 of Set 12 | barawe
# barawe not found. Skipping...
# Processing Record 37 of Set 12 | auki
# Processing Record 38 of Set 12 | ensley
# Processing Record 39 of Set 12 | hirara
# Processing Record 40 of Set 12 | viedma
# Processing Record 41 of Set 12 | juneau
# Processing Record 42 of Set 12 | aracaju
# Processing Record 43 of Set 12 | landeck
# Processing Record 44 of Set 12 | san vicente
# Processing Record 45 of Set 12 | nurobod
# Processing Record 46 of Set 12 | houma
# Processing Record 47 of Set 12 | tabuk
# Processing Record 48 of Set 12 | sancti spiritus
# Processing Record 49 of Set 12 | manokwari
# Processing Record 50 of Set 12 | kang
# Processing Record 1 of Set 13 | casale monferrato
# Processing Record 2 of Set 13 | fare
# Processing Record 3 of Set 13 | mehran
# Processing Record 4 of Set 13 | jahrom
# jahrom not found. Skipping...
# Processing Record 5 of Set 13 | la asuncion
# Processing Record 6 of Set 13 | ca mau
# Processing Record 7 of Set 13 | watsa
# Processing Record 8 of Set 13 | mayo
# Processing Record 9 of Set 13 | san-pedro
# Processing Record 10 of Set 13 | corrales
# Processing Record 11 of Set 13 | puerto madero
# Processing Record 12 of Set 13 | lompoc
# Processing Record 13 of Set 13 | roebourne
# Processing Record 14 of Set 13 | bilibino
# Processing Record 15 of Set 13 | ilhabela
# Processing Record 16 of Set 13 | constitucion
# Processing Record 17 of Set 13 | clacton-on-sea
# Processing Record 18 of Set 13 | orzu
# Processing Record 19 of Set 13 | borogontsy
# Processing Record 20 of Set 13 | solhan
# Processing Record 21 of Set 13 | kainantu
# Processing Record 22 of Set 13 | lovozero
# Processing Record 23 of Set 13 | asfi
# Processing Record 24 of Set 13 | numan
# Processing Record 25 of Set 13 | lagos
# Processing Record 26 of Set 13 | carnot
# Processing Record 27 of Set 13 | jaciara
# Processing Record 28 of Set 13 | rognan
# Processing Record 29 of Set 13 | srednekolymsk
# Processing Record 30 of Set 13 | sierra vista
# Processing Record 31 of Set 13 | yerbogachen
# Processing Record 32 of Set 13 | sault sainte marie
# Processing Record 33 of Set 13 | gambela
# Processing Record 34 of Set 13 | novorzhev
# Processing Record 35 of Set 13 | harper
# Processing Record 36 of Set 13 | lata
# Processing Record 37 of Set 13 | kasongo-lunda
# Processing Record 38 of Set 13 | marienburg
# Processing Record 39 of Set 13 | rovnoye
# Processing Record 40 of Set 13 | marktredwitz
# Processing Record 41 of Set 13 | san francisco del mar
# Processing Record 42 of Set 13 | jieshi
# Processing Record 43 of Set 13 | glenwood springs
# Processing Record 44 of Set 13 | kampene
# Processing Record 45 of Set 13 | tulagi
# Processing Record 46 of Set 13 | gravdal
# Processing Record 47 of Set 13 | tarauaca
# Processing Record 48 of Set 13 | el vigia
# Processing Record 49 of Set 13 | sheridan
# Processing Record 50 of Set 13 | kisangani
# Processing Record 1 of Set 14 | dzaoudzi
# Processing Record 2 of Set 14 | santa cruz del sur
# Processing Record 3 of Set 14 | ahualulco
# Processing Record 4 of Set 14 | itoman
# Processing Record 5 of Set 14 | macaubas
# Processing Record 6 of Set 14 | balkanabat
# Processing Record 7 of Set 14 | presidencia roque saenz pena
# Processing Record 8 of Set 14 | igrim
# Processing Record 9 of Set 14 | bubaque
# Processing Record 10 of Set 14 | dukat
# Processing Record 11 of Set 14 | conceicao do araguaia
# Processing Record 12 of Set 14 | karauzyak
# karauzyak not found. Skipping...
# Processing Record 13 of Set 14 | sembe
# Processing Record 14 of Set 14 | zhigalovo
# Processing Record 15 of Set 14 | atambua
# Processing Record 16 of Set 14 | tepechitlan
# Processing Record 17 of Set 14 | dauriya
# Processing Record 18 of Set 14 | xingcheng
# Processing Record 19 of Set 14 | ormara
# Processing Record 20 of Set 14 | tumannyy
# tumannyy not found. Skipping...
# Processing Record 21 of Set 14 | isilkul
# Processing Record 22 of Set 14 | betsiamites
# Processing Record 23 of Set 14 | cody
# Processing Record 24 of Set 14 | trat
# Processing Record 25 of Set 14 | jamame
# Processing Record 26 of Set 14 | campos altos
# Processing Record 27 of Set 14 | sudak
# Processing Record 28 of Set 14 | cam ranh
# Processing Record 29 of Set 14 | dianopolis
# dianopolis not found. Skipping...
# Processing Record 30 of Set 14 | basco
# Processing Record 31 of Set 14 | fatehpur
# Processing Record 32 of Set 14 | keti bandar
# Processing Record 33 of Set 14 | yichun
# Processing Record 34 of Set 14 | belaya gora
# Processing Record 35 of Set 14 | bemidji
# Processing Record 36 of Set 14 | ziro
# Processing Record 37 of Set 14 | chumikan
# Processing Record 38 of Set 14 | coro
# Processing Record 39 of Set 14 | wattegama
# Processing Record 40 of Set 14 | tateyama
# Processing Record 41 of Set 14 | namibe
# Processing Record 42 of Set 14 | ingham
# Processing Record 43 of Set 14 | toliary
# toliary not found. Skipping...
# Processing Record 44 of Set 14 | bonavista
# Processing Record 45 of Set 14 | villa carlos paz
# Processing Record 46 of Set 14 | killarney
# Processing Record 47 of Set 14 | novokizhinginsk
# Processing Record 48 of Set 14 | nargana
# Processing Record 49 of Set 14 | fairbanks
# Processing Record 50 of Set 14 | chara
# Processing Record 1 of Set 15 | soe
# Processing Record 2 of Set 15 | monrovia
# Processing Record 3 of Set 15 | bellavista
# Processing Record 4 of Set 15 | wilkie
# Processing Record 5 of Set 15 | palabuhanratu
# palabuhanratu not found. Skipping...
# Processing Record 6 of Set 15 | dongying
# Processing Record 7 of Set 15 | nichinan
# Processing Record 8 of Set 15 | olafsvik
# Processing Record 9 of Set 15 | berlevag
# Processing Record 10 of Set 15 | roma
# Processing Record 11 of Set 15 | dakar
# Processing Record 12 of Set 15 | ossora
# Processing Record 13 of Set 15 | nizhniy ingash
# Processing Record 14 of Set 15 | colesberg
# Processing Record 15 of Set 15 | alihe
# Processing Record 16 of Set 15 | kondoa
# Processing Record 17 of Set 15 | ngukurr
# ngukurr not found. Skipping...
# Processing Record 18 of Set 15 | bronnoysund
# Processing Record 19 of Set 15 | labutta
# labutta not found. Skipping...
# Processing Record 20 of Set 15 | bayir
# Processing Record 21 of Set 15 | kyren
# Processing Record 22 of Set 15 | noumea
# Processing Record 23 of Set 15 | jabiru
# jabiru not found. Skipping...
# Processing Record 24 of Set 15 | agirish
# Processing Record 25 of Set 15 | hovd
# Processing Record 26 of Set 15 | murdochville
# Processing Record 27 of Set 15 | karkaralinsk
# karkaralinsk not found. Skipping...
# Processing Record 28 of Set 15 | zapolyarnyy
# Processing Record 29 of Set 15 | krasnoselkup
# Processing Record 30 of Set 15 | sampit
# Processing Record 31 of Set 15 | sawtell
# Processing Record 32 of Set 15 | luanda
# Processing Record 33 of Set 15 | husavik
# Processing Record 34 of Set 15 | minervino murge
# Processing Record 35 of Set 15 | paka
# Processing Record 36 of Set 15 | ketchikan
# Processing Record 37 of Set 15 | kassala
# Processing Record 38 of Set 15 | carolina
# Processing Record 39 of Set 15 | galiwinku
# galiwinku not found. Skipping...
# Processing Record 40 of Set 15 | magadan
# Processing Record 41 of Set 15 | balagansk
# Processing Record 42 of Set 15 | kytlym
# kytlym not found. Skipping...
# Processing Record 43 of Set 15 | beinamar
# Processing Record 44 of Set 15 | naze
# Processing Record 45 of Set 15 | inirida
# Processing Record 46 of Set 15 | pavlodar
# Processing Record 47 of Set 15 | capinopolis
# Processing Record 48 of Set 15 | fuyu
# Processing Record 49 of Set 15 | dongsheng
# Processing Record 50 of Set 15 | lagunillas
# Processing Record 1 of Set 16 | jalu
# Processing Record 2 of Set 16 | mount pleasant
# Processing Record 3 of Set 16 | cooma
# Processing Record 4 of Set 16 | non sung
# Processing Record 5 of Set 16 | gizo
# Processing Record 6 of Set 16 | shimoda
# Processing Record 7 of Set 16 | ashibetsu
# Processing Record 8 of Set 16 | sinnamary
# Processing Record 9 of Set 16 | west helena
# Processing Record 10 of Set 16 | berdigestyakh
# Processing Record 11 of Set 16 | cabo san lucas
# Processing Record 12 of Set 16 | owensboro
# Processing Record 13 of Set 16 | coaraci
# Processing Record 14 of Set 16 | antibes
# Processing Record 15 of Set 16 | tabiauea
# tabiauea not found. Skipping...
# Processing Record 16 of Set 16 | milkovo
# Processing Record 17 of Set 16 | harindanga
# Processing Record 18 of Set 16 | angoche
# Processing Record 19 of Set 16 | karakol
# Processing Record 20 of Set 16 | joshimath
# Processing Record 21 of Set 16 | egvekinot
# Processing Record 22 of Set 16 | shenjiamen
# Processing Record 23 of Set 16 | camana
# Processing Record 24 of Set 16 | whithorn
# Processing Record 25 of Set 16 | ballina
# Processing Record 26 of Set 16 | kpandae
# Processing Record 27 of Set 16 | maniitsoq
# Processing Record 28 of Set 16 | basak
# Processing Record 29 of Set 16 | aqtobe
# Processing Record 30 of Set 16 | tadine
# Processing Record 31 of Set 16 | lubango
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 722

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# MAKE SURE TO CHANGE THIS BACK INTO THE REGULAR RUBRICK

# Use the city_data list to create a new pandas DataFrame.
# city_data_df = pd.DataFrame(city_data)

# These two lines of code are created to not have to run the REST API 'get' loop.
city_data_df = pd.DataFrame(pd.read_csv('Weather_Database/city_data_df.csv'))
city_data_df = city_data_df.drop(['Unnamed: 0'], axis=1)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Bansko      BG  41.8383   23.4885    291.90       100          66
# 1    Taoudenni      ML  22.6783   -3.9836    311.22        12           0
# 2     Cherskiy      RU  68.7500  161.3000    271.82        98         100
# 3   Kaitangata      NZ -46.2817  169.8464    275.74        92          11
# 4        Kapaa      US  22.0752 -159.3190    297.14        92          75
# 5  Yellowknife      CA  62.4560 -114.3525    280.13       100         100
# 6      Itarema      BR  -2.9248  -39.9167    304.70        50          30
# 7   Mahibadhoo      MV   3.7833   72.9667    301.11        76          90
# 8     Khatanga      RU  71.9667  102.5000    272.00        97         100
# 9       Nabire      ID  -3.3667  135.4833    297.80        90          86
#
#    Wind Speed Current Description
# 0        2.15       broken clouds
# 1        5.44           clear sky
# 2        1.09          light snow
# 3        1.43          few clouds
# 4        2.57       moderate rain
# 5        1.79     overcast clouds
# 6        8.51    scattered clouds
# 7        8.47     overcast clouds
# 8        6.76          light snow
# 9        1.37     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE
column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE
city_data_df = city_data_df.reindex(columns = column_order)

# Max Temp returns temperature in Kelvins; converting to farenheight
def klvnToFrnht(arg):
    F = ((arg - 273.15) * 9/5) + 32
    return F
# this works
for index, klvn in city_data_df['Max Temp'].iteritems():
    city_data_df['Max Temp'][index] = round(klvnToFrnht(klvn),2)
    
# Display sample data
# YOUR CODE HERE

city_data_df.head(10)
# Out:
# C:\Users\migal\AppData\Local\Temp\ipykernel_4496\2537034520.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   city_data_df['Max Temp'][index] = round(klvnToFrnht(klvn),2)
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Bansko      BG  41.8383   23.4885     65.75       100          66
# 1    Taoudenni      ML  22.6783   -3.9836    100.53        12           0
# 2     Cherskiy      RU  68.7500  161.3000     29.61        98         100
# 3   Kaitangata      NZ -46.2817  169.8464     36.66        92          11
# 4        Kapaa      US  22.0752 -159.3190     75.18        92          75
# 5  Yellowknife      CA  62.4560 -114.3525     44.56       100         100
# 6      Itarema      BR  -2.9248  -39.9167     88.79        50          30
# 7   Mahibadhoo      MV   3.7833   72.9667     82.33        76          90
# 8     Khatanga      RU  71.9667  102.5000     29.93        97         100
# 9       Nabire      ID  -3.3667  135.4833     76.37        90          86
#
#    Wind Speed Current Description
# 0        2.15       broken clouds
# 1        5.44           clear sky
# 2        1.09          light snow
# 3        1.43          few clouds
# 4        2.57       moderate rain
# 5        1.79     overcast clouds
# 6        8.51    scattered clouds
# 7        8.47     overcast clouds
# 8        6.76          light snow
# 9        1.37     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE

file_name = 'Weather_Database/WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE
city_data_df.to_csv(file_name)
